# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")

# %%
import pltx

# %%
import mpld3
# mpld3.enable_notebook()
mpld3.disable_notebook()

# %%
pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
# Out:
# [ 0.97432488 -0.12574199]
#
# 0.9743 x - 0.1257
# poly1d([ 0.97432488, -0.12574199])

# %%
pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title="RMS Deviations",xlabel="x (Input)",ylabel="sqrt[(Output-x)^2]",annotate_fit=True,marker='.')
plt.plot(input[::,2][391],np.sqrt((output[::,2]-input[::,2])**2)[391],'x',label="PGC 24286",color="red",markersize=12)
outlier_n=1677
plt.plot(input[::,2][outlier_n],np.sqrt((output[::,2]-input[::,2])**2)[outlier_n],'x',label="PGC 1921",color="blue",markersize=12)
outlier_n=267
plt.plot(input[::,2][outlier_n],np.sqrt((output[::,2]-input[::,2])**2)[outlier_n],'x',label="PGC 64633 (1)",color="orange",markersize=12)
outlier_n=800
plt.plot(input[::,2][outlier_n],np.sqrt((output[::,2]-input[::,2])**2)[outlier_n],'x',label="PGC 70291",color="green",markersize=12)
outlier_n=162
plt.plot(input[::,2][outlier_n],np.sqrt((output[::,2]-input[::,2])**2)[outlier_n],'x',label="PGC 64633 (2)",color="magenta",markersize=12)
from matplotlib.legend_handler import HandlerLine2D
# plt.legend(loc='lower left',prop={'size':8},numpoints=1)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.3),
          ncol=3, fancybox=True, shadow=False,numpoints=1,prop={'size':12})
# Out:
# [ 0.0378963   0.23217059]
#
# 0.0379 x + 0.2322

# %% [markdown]
# # PGC 24286

# %%
outlier_n = np.intersect1d(np.where(input[::,2]<-7.716)[0],np.where(input[::,2]>-7.718)[0])[0]
outlier_n
# Out:
# 391

# %% [markdown]
# #### Looking at the check image for Input

# %% [markdown]
# Inside input_mag, the object with this magnitude is in line 392 with RA,DEC (1.233114412000000044e+02 4.598974369999999823e+01 -7.716700000000000337e+00) using the LCDM box search, we find that this is PGC 23040. Copied the 23040/ folder over from bigdog and looked at the check images

# %%
print input[::,0][outlier_n]
print input[::,1][outlier_n]
print input[::,2][outlier_n]
# Out:
# 123.3114412
# 45.9897437
# -7.7167

# %% [markdown]
# This is object number __4__ in input.cat

# %%
cd 23040/
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline/23040

# %%
from IPython.core.display import Image
Image("Screen Shot 2015-05-20 at 5.35.28 PM.png", width=400)

# %% [markdown]
# This looks like a normal-sized, normal brightness-ed star.

# %% [markdown]
# #### Looking at the Check Images for the output

# %%
print output[::,0][outlier_n]
print output[::,1][outlier_n]
print output[::,2][outlier_n]
# Out:
# 123.3109443
# 45.9892751
# -9.1723

# %% [markdown]
# ObjID inside output.cat : __6__

# %%
Image("Screen Shot 2015-05-20 at 5.36.34 PM.png",width=400)

# %% [markdown]
# Even though the sources are matched, the large RC3 source was deblended into multiple objects, in the output image the RC3 object is separated into many objects.Different deblending might have changed the light contribution, giving us a different magnitude.

# %% [markdown]
# # PGC 1921

# %%
cd test/
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline/test

# %%
outlier_n = np.intersect1d(np.where(input[::,2]>-7.002202)[0],np.where(input[::,2]<-7.0021995)[0])[0]
print outlier_n
# Out:
# 1677

# %% [markdown]
#  PGC :__1921__

# %%
print input[::,0][outlier_n]
print input[::,1][outlier_n]
print input[::,2][outlier_n]
# Out:
# 7.848042
# 8.4606717
# -7.0022

# %% [markdown]
#  499     23.192   7.8480420  +8.4606717       1211       1084       1290       1179    24.218    12.134  -7.0022

# %%
print output[::,0][outlier_n]
print output[::,1][outlier_n]
print output[::,2][outlier_n]
# Out:
# 7.8479936
# 8.4606826
# -5.5486

# %%
cd 1921/
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline/test/1921

# %%
Image("Screen Shot 2015-05-21 at 6.02.41 AM.png",width=400)

# %%
Image("Screen Shot 2015-05-21 at 6.05.04 AM.png",width=300)

# %% [markdown]
# Again, it looks like it is a deblending issues.

# %% [markdown]
# # PGC 64633

# %%
outlier_n = np.intersect1d(np.where(input[::,2]>-2.224)[0],np.where(input[::,2]<-2.222)[0])[0]
print outlier_n
print input[::,0][outlier_n]
print input[::,1][outlier_n]
print input[::,2][outlier_n]
# Out:
# 267
# 306.152798
# 12.4302974
# -2.2231

# %% [markdown]
# 2219      1.540 306.1527980 +12.4302974          8       1450         14       1456     1.346     1.289  -2.2231

# %%
cd ../64633/
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline/test/64633

# %% [markdown]
# This is object number __333__ in input.cat

# %%
from IPython.core.display import Image
Image("Screen Shot 2015-05-21 at 6.29.38 AM.png", width=400)

# %%
Image("Screen Shot 2015-05-21 at 6.30.20 AM.png", width=400)

# %%
Image("Screen Shot 2015-05-21 at 6.35.35 AM.png", width=400)

# %%
print output[::,0][outlier_n]
print output[::,1][outlier_n]
print output[::,2][outlier_n]
# Out:
# 306.152563
# 12.4301851
# 0.2797

# %% [markdown]
# 307      0.983 306.1525630 +12.4301851          1        297          2        300     0.938     0.474   0.2797

# %% [markdown]
# Boundary Sources (not eliminated by the boundary source algorithm somehow..)

# %% [markdown]
# # PGC 70291

# %%
cd ../70291/
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline/test/70291

# %%
outlier_n = np.intersect1d(np.where(input[::,2]>-3.8582)[0],np.where(input[::,2]<-3.8576)[0])[0]
print outlier_n
# Out:
# 1652

# %% [markdown]
#         10      1.590 345.4893186 +15.9307778        176          1        179          3     0.948     0.696  -0.2132

# %%
print input[::,0][outlier_n]
print input[::,1][outlier_n]
print input[::,2][outlier_n]
# Out:
# 7.8853116
# 8.4382694
# -3.858

# %%
Image("Screen Shot 2015-05-21 at 6.59.43 AM.png",width=400)

# %% [markdown]
# Boundary Sources!

# %%
Image("Screen Shot 2015-05-21 at 6.59.16 AM.png",width=400)

# %% [markdown]
#     70      1.606 345.4889612 +15.9307486        519        187        528        195     1.531     1.472  -3.1112

# %%
print output[::,0][outlier_n]
print output[::,1][outlier_n]
print output[::,2][outlier_n]
# Out:
# 7.885283
# 8.4382652
# -4.0116

# %% [markdown]
# # PGC 64633

# %%
outlier_n = np.intersect1d(np.where(input[::,2]>-3.521)[0],np.where(input[::,2]<-3.52)[0])[0]
print outlier_n
# Out:
# 162

# %%
print input[::,0][outlier_n]
print input[::,1][outlier_n]
print input[::,2][outlier_n]
# Out:
# 306.1443216
# 12.4304376
# -3.5207

# %%
cd ../64633/
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline/test/64633

# %% [markdown]
#      2306      2.353 306.1443216 +12.4304376         32       1378         53       1389     1.957     1.807  -3.5207

# %%
Image("Screen Shot 2015-05-21 at 7.23.01 AM.png",width=400)

# %%
Image("Screen Shot 2015-05-21 at 7.22.48 AM.png",width=400)

# %%
print output[::,0][outlier_n]
print output[::,1][outlier_n]
print output[::,2][outlier_n]
# Out:
# 306.1443232
# 12.4304337
# -4.9576

# %%
Image("Screen Shot 2015-05-21 at 7.26.13 AM.png",width=400)

# %% [markdown]
#     185     20.550 306.1443232 +12.4304337         39        298         81        359    17.022     7.236  -4.9576

# %% [markdown]
# Another deblending issue on large sources

# %% [markdown]
# # Using a more stringent condition for boundary rejection

# %% [markdown]
# ``Github says that 27 sources was deleted because of this change.``
#
#  ``input_mag  | 27 ---------------------------``
#
#  ``output_mag | 27 ---------------------------``
#
#  ``2 files changed, 54 deletions(-)``
#  ``

# %% [markdown]
# Now after doubling the margin radius NUM_EDGE_REJECT= 204
#
# (Took out PGC 59028)

# %%
cd ..
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3-pipeline

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")
pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title="RMS Deviations",xlabel="x (Input)",ylabel="sqrt[(Output-x)^2]",annotate_fit=True,marker='.')
# Out:
# [ 0.03861753  0.22953977]
#
# 0.03862 x + 0.2295
# poly1d([ 0.03861753,  0.22953977])
