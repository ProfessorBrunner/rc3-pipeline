# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Astrometry

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")

# %%
import pltx

# %%
pltx.fit_and_plot(input[::,0],np.sqrt((output[::,0]-input[::,0])**2),title=" ",xlabel="Input RA",ylabel="RMS  RA",annotate_fit=True,marker='.')
# Out:
# [ -2.52526140e-09   1.64822684e-05]
#
# -2.525e-09 x + 1.648e-05
# poly1d([ -2.52526140e-09,   1.64822684e-05])

# %% [markdown]
# #### no systematic offset

# %%
pltx.fit_and_plot(input[::,0],output[::,0],title=" ",xlabel="Input RA",ylabel="Output RA",annotate_fit=True,marker='.')
# Out:
# [  9.99999995e-01   3.12590843e-07]
#
# 1 x + 3.126e-07
# poly1d([  9.99999995e-01,   3.12590843e-07])

# %%
def fit_and_plot(x,y,xlabel="",ylabel="",title="",zeroed=False,annotate_fit= True,right_words = False,error_bar="",sci_lim = False,annotate="",right_annotate=False,marker='o'):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.plot(x,y,'{}'.format(marker))
    z = np.polyfit(x,y, 1) 
    print z
    p = np.poly1d(z)
    print p
    if zeroed : 
        a = np.linspace(0,max(x))
    else:
        a = np.linspace(min(x),max(x))
    ax1.plot(a, p(np.linspace(min(x),max(x))),color="red")
    if annotate_fit: 
        slope = z[0]
        intercept = z[1]
        if right_words:    
            ax1.text(0.48,0.85,"y= %.9f x + %.9f"%(slope,intercept), fontsize=13,transform=ax1.transAxes)
        else:
            ax1.text(0.03,0.85,"y= %.9f x + %.9f"%(slope,intercept), fontsize=13,transform=ax1.transAxes)
    if title !="":
        plt.title(title,fontsize=13 )    
        plt.xlabel(xlabel,fontsize=12)
        plt.ylabel(ylabel,fontsize=12)
#     ax1 = fig.add_subplot(111)
#     ax1.text(0.03,0.8,"y= %.5f x %.5f"%(p[0],p[1]), fontsize=13,transform=ax.transAxes)
    if annotate!="":
        if right_annotate: 
            ax1.text(0.48,0.85,annotate, fontsize=13,transform=ax1.transAxes)
    if error_bar!="":
        ax1.errorbar(x, y, yerr=error_bar, fmt='o')
    if sci_lim:
        plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    plt.tick_params(axis='both', which='major', labelsize=12)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    return p

# %%
sns.set_style("white")
sns.set_style("ticks")

p1 =plt.subplot(212)

x = input[::,1]
y=np.sqrt((output[::,1]-input[::,1])**2)
p1.plot(x,y,',')
plt.xlabel("Input DEC")
plt.ylabel("RMS on DEC")
sns.despine()
z = np.polyfit(x,y, 1) 
print z
p = np.poly1d(z)
print p
a = np.linspace(min(x),max(x))
p1.plot(a, p(np.linspace(min(x),max(x))),color="red",linewidth=1.0)
slope = z[0]
intercept = z[1]
p1.text(0.03,0.85,"y= %.9f x + %.9f"%(slope,intercept), fontsize=13,transform=p1.transAxes)


p2 =plt.subplot(211)
plt.title("Astrometric Comparison of 12663 Sources",fontsize=15)
x = input[::,1]
y=output[::,1]
plt.xlabel("Input DEC")
plt.ylabel("Output DEC")
sns.despine()
z = np.polyfit(x,y, 1) 
print z
p = np.poly1d(z)
print p
a = np.linspace(min(x),max(x))


p2.plot(a, p(np.linspace(min(x),max(x))),color="red",linewidth=1.0)
p2.plot(x,y,'*',markersize=3)
slope = z[0]
intercept = z[1]
p2.text(0.03,0.85,"y= %.9f x + %.9f"%(slope,intercept), fontsize=13,transform=p2.transAxes)
plt.tight_layout()
sns.despine()
# Out:
# [ -6.52807965e-08   1.55254716e-05]
#
# -6.528e-08 x + 1.553e-05
# [  9.99999995e-01   1.00300713e-07]
#
# 1 x + 1.003e-07

# %%
pltx.fit_and_plot(input[::,1],np.sqrt((output[::,1]-input[::,1])**2),title="Astrometry",xlabel="Input DEC",ylabel="RMS on DEC",annotate_fit=True,marker='.')
pltx.fit_and_plot(input[::,1],output[::,1],title="Astrometry",xlabel="Input DEC",ylabel="Output DEC",annotate_fit=True,marker='.')
# Out:
# [ -6.52807965e-08   1.55254716e-05]
#
# -6.528e-08 x + 1.553e-05
# [  9.99999995e-01   1.00300713e-07]
#
# 1 x + 1.003e-07
# poly1d([  9.99999995e-01,   1.00300713e-07])

# %%
len(input[::,0])
# Out:
# 12663

# %% [markdown]
# # Python script that crops g band

# %%
import os
os.walk()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-526520ea619f> in <module>()
#       1 import os
# ----> 2 os.walk()
#
# TypeError: walk() takes at least 1 argument (0 given)

# %%
for PGC_dir in os.walk('.').next()[1][1:]:
    print PGC_dir
    if os.path.exists("{}/*.tiff".format(PGC_dir)):
        pass
    else: #No colored mosaices generated
        print "PGC{} needs to do cropping".format(PGC_dir)

# %%
os.walk('.').next()
# Out:
# ('.',
#  ['.ipynb_checkpoints'],
#  ['.DS_Store',
#   '__init__.py',
#   'Automating Outlier Rejection.ipynb',
#   'Boundary Sources Detection and Elimination.ipynb',
#   'bulk_run.py',
#   'bulk_run_dss.py',
#   'bulk_run_twoMass.py',
#   'catalog.py',
#   'catalog.pyc',
#   'catalogSubset.py',
#   'catalogSubset.txt',
#   'Debug Outlier (After Bkgrd Rect).ipynb',
#   'Debugging more outliers.ipynb',
#   'Debugging outlier galaxy PGC 11737.ipynb',
#   'default.conv',
#   'default.nnw',
#   'default.param',
#   'default.sex',
#   'dss.py',
#   'dssServer.py',
#   'dssServer.pyc',
#   'dual.sh',
#   'failed_msubimage',
#   'flux_preserved.py',
#   'flux_preserved_orig.py',
#   'gator.py',
#   'gator.pyc',
#   'Generating rc3_subsample for 500 random test.ipynb',
#   'input_mag',
#   'input_mag_delta',
#   'input_mag_dual',
#   'License',
#   'mosaic.cat',
#   'mwd.py',
#   'mwd.pyc',
#   'nohup.out',
#   'num.txt',
#   'out_mag_lst = []',
#   'output.cat',
#   'output_mag',
# ...

# %% [markdown]
# # Photometry

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")
# pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title="Photometric Comparison of 12663 Sources",xlabel="Input MAG_ISOCORR",ylabel="RMS Deviation",annotate_fit=True,marker=',')
plt.ylim(-0.3,2)
#"$\sqrt{(Output-Input)^2}})$
# Out:
# [ 0.02492101  0.14127635]
#
# 0.02492 x + 0.1413
# (-0.3, 2)

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")
sns.set_style("white")
sns.set_style("ticks")
# pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title=" ",xlabel="Input MAG_ISOCORR",ylabel="RMS Deviation",annotate_fit=True,marker=',')
plt.title("Photometric Comparison of 12663 Sources",fontsize=15)
plt.ylim(-0.3,2)
#"$\sqrt{(Output-Input)^2}})$
sns.despine()
# Out:
# [ 0.02492101  0.14127635]
#
# 0.02492 x + 0.1413

# %%
mean(np.sqrt((output[::,2]-input[::,2])**2))
# Out:
# 0.086460270078180537

# %%
len(input[::,2])
# Out:
# 12663

# %% [markdown]
# #### Number of sources with RMS >0.1

# %%
n=len(np.where(np.sqrt((output[::,2]-input[::,2])**2)>0.1)[0])
print n
# Out:
# 2224

# %%
n/12663.*100
# Out:
# 17.562978757008608

# %%
import matplotlib.pyplot as plt
from numpy.random import normal
rms = np.sqrt((output[::,2]-input[::,2])**2)
plt.hist(rms,35,weights=np.ones(len(rms))*0.007897022822395957)
plt.title("Histogram Distribution of Source RMS",fontsize=13)
plt.xlabel("MAG ISOCORR RMS",fontsize=13 )
plt.ylabel("% of all sources",fontsize=13)
plt.xlim(0,2)
plt.show()

# %%
inputerr = np.loadtxt("input_mag_err")
outputerr = np.loadtxt("output_mag_err")

# %%
print mean(inputerr[::,2])
print mean(np.sqrt(outputerr[::,2]**2))
# Out:
# 0.088262380301
# 0.0582224842681

# %%
print mean(np.sqrt(inputerr[::,2]**2))
print mean(np.sqrt(outputerr[::,2]**2))
print max(abs(inputerr[::,2]))
print max(abs(outputerr[::,2]))
# Out:
# 0.088262380301
# 0.0582224842681
# 0.2574
# 0.2574

# %%
import seaborn as sns

# %%
rms = np.sqrt((output[::,2]-input[::,2])**2)
inputerrrms = np.sqrt(inputerr[::,2])**2
outputerrrms = np.sqrt(outputerr[::,2])**2
bins = numpy.linspace(-10, 10, 150)
sns.set_style("whitegrid")
sns.set_style("ticks")
plt.hist(outputerrrms,bins,alpha=0.7,weights=np.ones(len(outputerrrms))*0.007897022822395957,label="Output MAG ISOCORR ERR")
plt.hist(inputerrrms,bins,alpha=0.7,weights=np.ones(len(inputerrrms))*0.007897022822395957,label="Input MAG ISOCORR ERR")
plt.hist(rms,bins,alpha=0.7,weights=np.ones(len(rms))*0.007897022822395957,label="Input and Output RMS")
sns.despine()
plt.title("Histogram Distribution of Source RMS",fontsize=15)
plt.xlabel("MAG ISOCORR RMS",fontsize=13 )
plt.ylabel("% of all sources",fontsize=13)
plt.xlim(0,2)
plt.legend(loc='upper right',fontsize=13)
plt.show()

# %% [markdown]
# # Number rejected

# %% [markdown]
# NUM_RC3_REJECT:  21
#
# NUM_EDGE_REJECT:  40
#
# PGC: 50305
#
# NUM_RC3_REJECT:  0
#
# NUM_EDGE_REJECT:  1
#
# PGC: 62225
#
# NUM_RC3_REJECT:  32
#
# NUM_EDGE_REJECT:  24
#
# PGC: 31429
#
# NUM_RC3_REJECT:  41
#
# NUM_EDGE_REJECT:  362
#
# PGC: 33371

# %%
print "RC3 Reject",21+32+41
# Out:
# RC3 Reject 94

# %%
print "EDGE Reject", 40+362+24+1
# Out:
# EDGE Reject 427
