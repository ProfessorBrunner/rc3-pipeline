# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls *.txt
# Out:
# num.txt                      rc3_updated.txt              stiff_error.txt
# rc3_ra_dec_diameter_pgc.txt  sample.txt
# rc3_subsample.txt            single.txt

# %%
# cat rc3_ra_dec_diameter_pgc.txt

# %%
mega_ra = []
mega_dec = []
coord =[]
with open("rc3_ra_dec_diameter_pgc.txt",'r') as f:
    for line in f:
#         a = str(line)[0]
        info = line.split()
        mega_ra.append(float(info[0]))
        mega_dec.append(float(info[1]))
        coord.append([float(info[0]),float(info[1]),float(info[2]),int(info[3])])
#         print info
coord=np.array(coord)

# %%
plt.plot(mega_ra,mega_dec,'.')

# %% [markdown]
# Code from Eduardo Martin (http://balbuceosastropy.blogspot.com/2013/09/the-mollweide-projection.html)

# %%
def plot_mwd(RA,Dec,org=0,title='Mollweide projection', projection='mollweide'):
    ''' RA, Dec are arrays of the same length.
    RA takes values in [0,360), Dec in [-90,90],
    which represent angles in degrees.
    org is the origin of the plot, 0 or a multiple of 30 degrees in [0,360).
    title is the title of the figure.
    projection is the kind of projection: 'mollweide', 'aitoff', 'hammer', 'lambert'
    '''
    x = np.remainder(RA+360-org,360) # shift RA values
    ind = x>180
    x[ind] -=360    # scale conversion to [-180, 180]
    x=-x    # reverse the scale: East to the left
    tick_labels = np.array([150, 120, 90, 60, 30, 0, 330, 300, 270, 240, 210])
    tick_labels = np.remainder(tick_labels+360+org,360)
    fig = figure(figsize=(10, 5))
    ax = fig.add_subplot(111, projection=projection, axisbg ='LightCyan')
    ax.scatter(np.radians(x),np.radians(Dec),marker='.',color='blue')  # convert degrees to radians
    ax.set_xticklabels(tick_labels)     # we add the scale on the x axis
    ax.set_title(title)
    ax.title.set_fontsize(15)
    ax.set_xlabel("RA")
    ax.xaxis.label.set_fontsize(12)
    ax.set_ylabel("Dec")
    ax.yaxis.label.set_fontsize(12)
    ax.grid(True)

# %%
plot_mwd(coord[:,0],coord[:,1], org=90, title ='All RC3 Galaxies')
# Out:
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/projections/geo.py:485: RuntimeWarning: invalid value encountered in arcsin
#   theta = np.arcsin(y / np.sqrt(2))

# %%
shape(coord)
# Out:
# (23011, 4)

# %%
coord[1]
# Out:
# array([  0.03625   ,  -6.37472222,   0.02581361,  12.        ])

# %%
import random
rc3_subsample = []
for i in np.arange(100):
    n = randint(23011)
#     print (coord[n,0],coord[n,1])
    rc3_subsample.append((coord[n,0],coord[n,1],coord[n,2],coord[n,3]))

# %%
rc3_subsample = np.array(rc3_subsample)
plot_mwd(rc3_subsample[:,0],rc3_subsample[:,1], org=90, title ='All RC3 Galaxies')

# %%
rc3_subsample[0] #for each rc3 galaxy we store (ra,dec,radius,pgc)
# Out:
# array([  1.09861250e+02,  -3.56569444e+01,   5.27046278e-02,
#          2.06760000e+04])

# %%
subsample_radius = rc3_subsample[::,2]
histo = plt.hist(subsample_radius,100)
mu = mean(subsample_radius)
sig = np.std(subsample_radius)
plt.xlim(0,mu+3*sig)
plt.title("Size distribution of subsample RC3 Galaxies",fontsize=12)
plt.xlabel("Radius [deg]",fontsize=12)
plt.ylabel("Number of RC3 in subsample",fontsize=12)

# %%
np.savetxt("rc3_subsample.txt",rc3_subsample)

# %%
cat rc3_subsample.txt
# Out:
# 1.098612499999999983e+02 -3.565694444439999700e+01 5.270462777490000222e-02 2.067600000000000000e+04
# 1.464254166670000075e+02 -1.432750000000000057e+01 6.192253830669999792e-02 2.798200000000000000e+04
# 1.787470833330000062e+02 5.849361111110000166e+01 4.590381181409999845e-02 3.738600000000000000e+04
# 3.810000000000000142e+01 3.549499999999999744e+01 4.091181534320000035e-02 9.665000000000000000e+03
# 4.452083333330000059e+00 -6.835888888889999748e+01 1.958162595480000129e-02 1.162000000000000000e+03
# 1.934499999999999886e+02 2.959611111110000081e+01 1.101155748880000042e-02 4.383400000000000000e+04
# 2.024133333329999971e+02 4.538750000000000284e+01 3.563270156299999658e-02 4.737100000000000000e+04
# 3.013708333330000144e+01 3.246722222220000020e+01 1.555423837769999949e-02 7.614000000000000000e+03
# 1.566804166670000029e+02 5.722749999999999915e+01 2.300640445609999918e-02 3.068600000000000000e+04
# 3.180000000000000071e+01 4.377777777779999724e+01 2.522602085769999961e-02 8.082000000000000000e+03
# 3.378204166670000177e+02 -4.648111111109999882e+01 1.555423837769999949e-02 6.905000000000000000e+04
# 3.189250000000000114e+02 1.737999999999999901e+01 1.870030760909999895e-02 6.643400000000000000e+04
# 1.452358333329999880e+02 2.777777777780000079e+01 1.745214250240000042e-02 2.763700000000000000e+04
# 2.703758333330000028e+02 -6.374750000000000227e+01 1.870030760909999895e-02 6.128800000000000000e+04
# 1.861229166669999984e+02 -2.163194444439999842e+01 2.248271475480000114e-02 4.037900000000000000e+04
# 3.916208333329999647e+01 -5.486027777780000037e+01 3.325437198270000255e-02 9.907000000000000000e+03
# 1.761966666669999881e+02 1.987277777779999965e+01 8.162980339130000360e-03 3.656700000000000000e+04
# 5.664999999999999858e+01 -4.452777777779999724e+00 4.091181534320000035e-02 1.382000000000000000e+04
# 6.046458333329999846e+01 -4.194194444440000069e+01 2.197094568650000135e-02 1.431900000000000000e+04
# 1.767062500000000114e+02 -3.822777777779999830e+00 1.666666669999999906e-02 3.674200000000000000e+04
# 2.822416666670000041e+01 3.605333333330000301e+01 2.300640445609999918e-02 6.972000000000000000e+03
# 5.961666666669999870e+01 -4.022833333330000016e+01 1.555423837769999949e-02 1.419600000000000000e+04
# 2.418549999999999898e+02 1.042583333329999995e+01 1.958162595480000129e-02 5.721600000000000000e+04
# 3.299999999999999822e+00 1.702527777779999951e+01 3.818112762249999820e-02 8.890000000000000000e+02
# 2.597958333329999903e+01 1.380611111109999989e+01 3.998054873029999873e-02 6.364000000000000000e+03
# 1.695500000000000114e+02 2.828027777779999852e+01 2.300640445609999918e-02 3.455200000000000000e+04
# 1.996433333329999869e+02 -2.129944444439999884e+01 3.032834770419999895e-02 4.637300000000000000e+04
# 2.011066666670000131e+02 3.096000000000000085e+01 1.293745196969999997e-02 4.687200000000000000e+04
# 1.651750000000000114e+02 6.132944444440000353e+01 3.563270156299999658e-02 3.318800000000000000e+04
# 3.410566666670000018e+02 -6.404222222219999594e+01 4.806719181489999687e-02 6.962000000000000000e+04
# 2.889045833330000050e+02 -4.788694444440000098e+01 2.830406093100000173e-02 6.297600000000000000e+04
# 3.425249999999999773e+02 -1.023333333330000094e+00 1.913589372989999912e-02 6.982900000000000000e+04
# 6.164208333330000045e+01 3.128194444440000055e+01 2.581361036680000082e-02 1.446800000000000000e+04
# 3.098245833330000210e+02 -4.460499999999999687e+01 2.197094568650000135e-02 6.513700000000000000e+04
# 1.408170833329999994e+02 -7.272222222219999477e-01 2.465180651880000129e-02 2.657600000000000000e+04
# 2.219370833330000039e+02 -7.330750000000000455e+01 4.918682054279999855e-02 5.283700000000000000e+04
# 2.535925000000000011e+02 4.133583333330000187e+01 1.485418233189999930e-02 5.923800000000000000e+04
# 2.069399999999999977e+02 3.825888888890000317e+01 1.207393269209999960e-02 4.892000000000000000e+04
# 6.363000000000000256e+01 -5.079388888889999976e+01 2.050447955450000054e-02 1.472000000000000000e+04
# 2.996262500000000273e+02 -4.081416666669999671e+01 2.300640445609999918e-02 6.390600000000000000e+04
# 1.954550000000000125e+02 -8.337500000000000355e+00 4.485891348849999766e-02 4.493100000000000000e+04
# 1.183125000000000071e+01 1.470333333329999981e+01 1.555423837769999949e-02 2.768000000000000000e+03
# 6.788333333329999775e+00 -4.098333333330000272e+01 2.003774061700000150e-02 1.673000000000000000e+03
# 6.991791666669999472e+01 -1.325027777779999916e+01 2.765978184590000069e-02 1.575400000000000000e+04
# 1.664654166669999995e+02 -9.703055555560000656e+00 2.465180651880000129e-02 3.355500000000000000e+04
# 1.788000000000000114e+02 4.936111111109999783e-01 2.248271475480000114e-02 3.740700000000000000e+04
# 3.632999999999999829e+01 -5.772333333329999761e+01 2.300640445609999918e-02 9.191000000000000000e+03
# 4.025208333329999988e+01 3.907194444440000325e+01 5.913556499049999610e-03 1.016900000000000000e+04
# 1.970070833329999971e+02 2.676527777780000150e+01 1.126804961239999923e-02 4.550900000000000000e+04
# 1.823620833329999869e+02 -2.428500000000000014e+01 1.386272954609999927e-02 3.863300000000000000e+04
# 1.592483333330000050e+02 1.813694444440000098e+01 5.150492397820000123e-02 3.150800000000000000e+04
# 1.847412500000000080e+02 4.730444444439999785e+01 3.103478567310000158e-01 3.960000000000000000e+04
# 1.295749999999999886e+02 6.904250000000000398e+01 1.628728704850000014e-02 2.428100000000000000e+04
# 2.191958333330000031e+01 3.718305555559999931e+01 3.175767869619999795e-02 5.450000000000000000e+03
# 1.787750000000000057e+02 7.942722222220000106e+01 1.235517071309999958e-02 3.739900000000000000e+04
# 3.396625000000000227e+02 2.861777777780000065e+01 1.745214250240000042e-02 6.939400000000000000e+04
# 5.744500000000000028e+01 -3.593444444440000041e+01 1.520018068630000010e-02 1.393000000000000000e+04
# 2.078841666669999881e+02 -2.663194444439999842e+01 1.520018068630000010e-02 4.920000000000000000e+04
# 1.607666666669999955e+01 -4.014888888889999663e+01 1.628728704850000014e-02 3.820000000000000000e+03
# 1.733562499999999886e+02 -2.383055555559999927e+00 1.485418233189999930e-02 3.568200000000000000e+04
# 1.612750000000000128e+01 -3.365388888889999919e+01 2.098209023849999938e-02 3.829000000000000000e+03
# 4.257374999999999687e+01 -8.597222222219999210e+00 3.731201905079999798e-02 1.076600000000000000e+04
# 1.508499999999999943e+02 1.309416666669999962e+01 1.705488323880000046e-02 2.915600000000000000e+04
# 4.078291666669999671e+01 -8.774722222219999423e+00 1.913589372989999912e-02 1.029000000000000000e+04
# 3.809458333330000102e+01 4.219888888890000089e+01 2.581361036680000082e-02 9.663000000000000000e+03
# 2.731250000000000000e+02 1.861638888890000132e+01 4.091181534320000035e-02 6.155800000000000000e+04
# 2.832445833329999800e+02 -4.253833333330000244e+01 2.765978184590000069e-02 6.252900000000000000e+04
# 1.567070833330000141e+02 3.492000000000000171e+01 2.197094568650000135e-02 3.069400000000000000e+04
# 3.111374999999999886e+02 -6.874722222219999423e+01 6.947823071729999911e-02 6.529500000000000000e+04
# 3.664999999999999858e+01 2.275305555559999959e+01 2.300640445609999918e-02 9.293000000000000000e+03
# 2.228499999999999943e+02 9.335277777780000008e+00 2.098209023849999938e-02 5.305400000000000000e+04
# 1.840041666669999927e+02 4.650555555560000442e+00 1.207393269209999960e-02 3.926500000000000000e+04
# 1.417470833330000062e+02 -1.210916666670000019e+01 3.563270156299999658e-02 2.679600000000000000e+04
# 1.583995833330000096e+02 -2.745499999999999829e+01 4.485891348849999766e-02 3.121700000000000000e+04
# 1.068024999999999949e+02 1.417666666669999920e+01 1.745214250240000042e-02 2.017600000000000000e+04
# 2.737500000000000000e+02 7.102805555560000528e+01 2.354229245749999908e-02 6.164100000000000000e+04
# 1.316395833329999903e+02 4.843055555560000158e+01 1.386272954609999927e-02 2.465400000000000000e+04
# 1.943937500000000114e+02 2.848222222220000077e+01 3.032834770419999895e-02 4.432900000000000000e+04
# 2.228020833330000130e+02 -2.044222222220000162e+01 3.646269380540000105e-02 5.303500000000000000e+04
# 1.766345833329999948e+02 -3.009944444439999955e+01 2.354229245749999908e-02 3.671900000000000000e+04
# 3.526112499999999841e+02 -1.772916666669999941e+01 1.628728704850000014e-02 7.161800000000000000e+04
# 3.077570833330000255e+02 -1.935833333329999961e+00 2.354229245749999908e-02 6.486400000000000000e+04
# 3.500816666669999790e+02 3.549138888889999777e+01 2.098209023849999938e-02 7.112400000000000000e+04
# 1.377570833329999971e+02 3.209499999999999886e+01 2.098209023849999938e-02 2.589300000000000000e+04
# 3.437845833330000005e+02 3.130861111109999939e+01 1.520018068630000010e-02 7.000000000000000000e+04
# 1.824499999999999886e+02 4.298250000000000171e+01 2.300640445609999918e-02 3.867400000000000000e+04
# 1.347858333329999994e+02 1.114972222219999942e+01 2.050447955450000054e-02 2.523800000000000000e+04
# 1.473000000000000114e+02 6.942222222220000560e+01 2.963799022659999866e-02 2.822500000000000000e+04
# 1.675000000000000044e+00 5.103888888890000253e+00 1.591654313219999922e-02 5.110000000000000000e+02
# 2.079874999999999829e+01 3.352972222220000020e+01 2.830406093100000173e-02 5.061000000000000000e+03
# 1.497341666670000109e+02 1.442111111110000010e+01 2.003774061700000150e-02 2.883300000000000000e+04
# 3.924458333329999959e+01 -5.349444444439999558e+00 2.098209023849999938e-02 9.923000000000000000e+03
# 2.502500000000000000e+02 6.239333333329999931e+01 1.745214250240000042e-02 5.875000000000000000e+04
# 2.562520833329999732e+02 -1.541388888890000031e+00 2.830406093100000173e-02 5.956900000000000000e+04
# 5.551624999999999943e+01 1.598805555560000080e+01 2.098209023849999938e-02 1.358700000000000000e+04
# 1.153037499999999937e+02 4.767194444439999756e+01 1.785865512300000013e-02 2.157800000000000000e+04
# 3.697749999999999915e+01 2.033222222219999864e+01 3.402896581260000247e-02 9.379000000000000000e+03
# 1.760233333330000107e+02 2.988694444440000098e+01 3.249741006100000107e-02 3.649500000000000000e+04
# 2.279250000000000114e+02 3.266194444439999955e+01 1.666666669999999906e-02 5.423800000000000000e+04
# 2.164041666669999842e+01 3.161277777780000164e+01 1.591654313219999922e-02 5.364000000000000000e+03
