# %% [markdown]
# # Comparing the output mosaics with the SDSS Magnitudes

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import astropy.io.fits as pf
import sqlcl
import os
import glob
import shutil

# %%
cd ../../rc3_data_product/rc3
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3_data_product/rc3

# %%
cd ../../
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014

# %%
cd ..
# Out:
# /Users/dorislee/Desktop/Doris_Files/Fall2014/GSoC2014/rc3_data_product/rc3

# %%
MEGA_in =[]
MEGA_out =[]
for PGC in [110,121,1665,1654,1614,1107]:
#     PGC=121
    os.chdir("{}/sdss/".format(PGC))
    os.system("sex  SDSS_r_{}.fits".format(PGC))
    os.rename("test.cat","output.cat")
    catalog = np.loadtxt("output.cat")

    fits_file = "SDSS_r_{}.fits".format(PGC)
    x = pf.getdata(fits_file)
    hdr = pf.getheader(fits_file)
    ra = hdr['RA']
    dec = hdr['DEC']
    margin  = 0.22528 #Choose the biggest, because I'm not sure if this is aligned correctly, worse case worse you just spent more time trying to match sources.
    result = sqlcl.query("SELECT ra, dec, modelMag_r  FROM PhotoObj as po WHERE po.ra between {0}-{2} and  {0}+{2} and po.dec between {1}-{2} and  {1}+{2}".format(str(ra),str(dec),str(margin))).readlines()
    # result = sqlcl.query("SELECT ra, dec, modelMag_r  FROM PhotoObj as po WHERE po.ra between {0} and  {0}+{2} and po.dec between {1} and  {1}+{2}".format(str(ra),str(dec),str(margin))).readlines()
    data =[]
    count =0
    # print (result)
    for i in result:
    #     print(i)
        if count>1:
            list =i.split(',')
    #         print list
            data.append([float(list[0]),float(list[1]),float(list[2][:-1])])
        count += 1 
    data = np.array(data)
    #Create and Save Dummy
    dummy = np.zeros_like(data[::,0],dtype=int)
    sdss_result = np.array([np.arange(len(data[::,0])),dummy, data[::,0], data[::,1],dummy,dummy,dummy,dummy,dummy,dummy,data[::,2]]).T
    np.savetxt("sdds_output",sdss_result)
    result = sdss_source_matching("sdds_output","output.cat",DEBUG_astrometry_check=True)
    os.chdir("../../")
    MEGA_in.append(result[0])
    MEGA_out.append(result[1])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-145-5c8eda0686c7> in <module>()
#       5     os.chdir("{}/sdss/".format(PGC))
#       6     os.system("sex  SDSS_r_{}.fits".format(PGC))
# ----> 7     os.rename("test.cat","output.cat")
#       8     catalog = np.loadtxt("output.cat")
#       9
#
# OSError: [Errno 2] No such file or directory

# %%
plt.xlabel("SDSS_MAG")
plt.ylabel("OUTPUT_MOSAIC_MAG")
plt.plot(result[0],result[1],'o')

# %%
def sdss_source_matching(cat1,cat2,DEBUG_astrometry_check=False):
    '''
    Feed in two catalogs, get back matched magnitude pairs
    '''
    import numpy as np
    import matplotlib.pyplot as plt
    mega_x_input = []
    mega_x_output=[]
    k=-11 
    # Setting up for catalog 1
    mag_lst = []   
    catalog = open(cat1,'r')
    coord = []
    for line in catalog:
        line = line.split()
        if (line[0]!='#'):
            ra = float(line[2])
            dec = float(line[3])
            mag=float(line[10])#*10**(9)
            coord.append([ra,dec])
            mag_lst.append(mag)
            # break
    coord = np.array(coord)
    ra_lst = coord[::,0]
    dec_lst = coord[::,1]

    # Setting up for catalog 2 
    out_mag_lst = []   
    catalog2 = open(cat2,'r')
    out_coord = []
    for line in catalog2:
        line = line.split()
        if (line[0]!='#'):
            ra = float(line[2])
            dec = float(line[3])
            mag=float(line[10])#*10**(9)
            out_coord.append([ra,dec])
            out_mag_lst.append(mag)
    out_coord = np.array(out_coord)
    out_ra_lst = out_coord[::,0]
    out_dec_lst = out_coord[::,1]
    if DEBUG_astrometry_check:
        plt.figure()
        plt.plot(out_ra_lst,out_dec_lst,'.')
        plt.plot(ra_lst,dec_lst,'.',color="red")
        plt.xlabel("RA")
        plt.ylabel("DEC")
    # Source Matching code 
    mag_lst = np.array(mag_lst)
    idx = np.where(abs(mag_lst-out_mag_lst[0])<0.1)
    epsilon = 0.001#small margin
    idx_ra = np.intersect1d(np.where(min(out_ra_lst)<coord[::,0]+epsilon),np.where(coord[::,0]<max(out_ra_lst)+epsilon))
    idx_dec = np.intersect1d(np.where(min(out_dec_lst)<coord[::,1]+epsilon),np.where(coord[::,1]<max(out_dec_lst)+epsilon))
    intersect = np.intersect1d(idx_ra,idx_dec)
    input_within_region  = coord[intersect]
    input_within_region_with_mag =np.c_[input_within_region, mag_lst[intersect]] 
    if DEBUG_astrometry_check:
        plt.figure()
        plt.plot(input_within_region[::,0],input_within_region[::,1],'o')
        plt.plot(out_ra_lst,out_dec_lst,'o',color="red",ms=4)
    matched_coord = []
    for i in out_coord:
        for o in input_within_region:
            bool = (abs(i-o)<5e-4)
            if(bool[0] and bool[1]):
                matched_coord.append([i,o])
    out_coord_mag = np.c_[out_coord, out_mag_lst] 
    # Matching coordinates with output magnitudes
    matched_coord=np.array(matched_coord)
    matched_mag_lst_output =[]
    for i in matched_coord[::,0]:
        for j in out_coord_mag:
            if i[0]==j[0]:
                matched_mag_lst_output.append(j[2])
    # Matching coordinates with input magnitudes
    matched_mag_lst_input =[]
    for i in matched_coord[::,1]:
        for j in input_within_region_with_mag:
            if i[0]==j[0]:
                matched_mag_lst_input.append(j[2])
#             plt.plot(matched_mag_lst_output,matched_mag_lst_input,'o')
    mega_x_input.append(matched_mag_lst_input)
    mega_x_output.append(matched_mag_lst_output)
    return np.array([mega_x_input[0],mega_x_output[0]])

# %%
result = sdss_source_matching("sdds_output","output.cat",DEBUG_astrometry_check=True)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-152-e3143ea95894> in <module>()
# ----> 1 result = sdss_source_matching("sdds_output","output.cat",DEBUG_astrometry_check=True)
#
# <ipython-input-151-5888b27bc423> in sdss_source_matching(cat1, cat2, DEBUG_astrometry_check)
#      10     # Setting up for catalog 1
#      11     mag_lst = []
# ---> 12     catalog = open(cat1,'r')
#      13     coord = []
#      14     for line in catalog:
#
# IOError: [Errno 2] No such file or directory: 'sdds_output'

# %%
MEGA_in[0]
#,list(MEGA_in[1]))
# # MEGA_in[0]
# np.concatenate()
# Out:
# array([ 12.17198,  15.5407 ,  17.84249,  21.51549,  19.23341,  22.33301,
#         19.60969,  21.81872,  16.18483,  19.13093,  20.57461,  21.89552])

# %%
from compiler.ast import flatten
MEGA_in = flatten(MEGA_in)
MEGA_out = flatten(MEGA_out)
# Out:
# -c:1: DeprecationWarning: The compiler package is deprecated and removed in Python 3.x.

# %%
plt.xlabel("SDSS_MAG")
plt.ylabel("OUTPUT_MOSAIC_MAG")
plt.plot(MEGA_in,MEGA_out,'o')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-f6d217de4af7> in <module>()
#       1 plt.xlabel("SDSS_MAG")
#       2 plt.ylabel("OUTPUT_MOSAIC_MAG")
# ----> 3 plt.plot(MEGA_in,MEGA_out,'o')
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4136
#    4137         for line in self._get_lines(*args, **kwargs):
# -> 4138             self.add_line(line)
#    4139             lines.append(line)
#    4140
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/axes.pyc in add_line(self, line)
#    1495             line.set_clip_path(self.patch)
#    1496
# -> 1497         self._update_line_limits(line)
#    1498         if not line.get_label():
#    1499             line.set_label('_line%d' % len(self.lines))
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/axes.pyc in _update_line_limits(self, line)
#    1506         Figures out the data limit of the given line, updating self.dataLim.
#    1507         """
# -> 1508         path = line.get_path()
#    1509         if path.vertices.size == 0:
#    1510             return
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     741         """
#     742         if self._invalidy or self._invalidx:
# --> 743             self.recache()
#     744         return self._path
#     745
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     418                 x = ma.asarray(xconv, np.float_)
#     419             else:
# --> 420                 x = np.asarray(xconv, np.float_)
#     421             x = x.ravel()
#     422         else:
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     460
#     461     """
# --> 462     return array(a, dtype, copy=False, order=order)
#     463
#     464 def asanyarray(a, dtype=None, order=None):
#
# ValueError: setting an array element with a sequence.

# %%
plt.xlabel("SDSS_MAG")
plt.ylabel("OUTPUT_MOSAIC_MAG")
plt.plot(result[0],result[1],'o')
