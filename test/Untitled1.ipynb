# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pltx

# %% [markdown]
# ### Done Using MAG_AUTO

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")
pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
# Out:
# [ 0.9914311  -0.03355409]
#
# 0.9914 x - 0.03355
# poly1d([ 0.9914311 , -0.03355409])

# %%
pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title="MAG_AUTO",xlabel="x (Input)",ylabel="sqrt[(Output-x)^2]",annotate_fit=True,marker='.')
# Out:
# [ 0.02492101  0.14127635]
#
# 0.02492 x + 0.1413
# poly1d([ 0.02492101,  0.14127635])

# %% [markdown]
# ### Decreasing the criterium of what is defined as an outlier (Going back to using MAG_ISO_CORR)

# %%
Oops this was actually the mag_iso_corr plotted here, since I didn't change it properly in the default.param.

# %%
# input = np.loadtxt("input_mag")
# output = np.loadtxt("output_mag")
# # pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
# pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title="MAG_ISO_CORR",xlabel="x (Input)",ylabel="sqrt[(Output-x)^2]",annotate_fit=True,marker='.')

# %% [markdown]
# While we are here, we might as well take a look at the error on these measurements:

# %%
print mean(output[::,2])
print mean(input[::,2])
# Out:
# 0.0582224842681
# 0.088262380301

# %% [markdown]
# Maybe try creating the histograms that the SWIRE teams had and see how much stuff is in each bin ??

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")
# pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
pltx.fit_and_plot(input[::,2],np.sqrt((output[::,2]-input[::,2])**2),title="RMS Deviations",xlabel="x (Input)",ylabel="sqrt[(Output-x)^2]",annotate_fit=True,marker='.')
# Out:
# [ 0.02492101  0.14127635]
#
# 0.02492 x + 0.1413
# poly1d([ 0.02492101,  0.14127635])

# %%
print mean(np.sqrt((output[::,2]-input[::,2])**2))
# Out:
# 0.0864602700782

# %%
len(rms)
# Out:
# 12663

# %%
1./12663.*100
# Out:
# 0.007897022822395957

# %%
3.5/0.1
# Out:
# 35.0

# %%
import matplotlib.pyplot as plt
from numpy.random import normal
rms = np.sqrt((output[::,2]-input[::,2])**2)
plt.hist(rms,35,weights=np.ones(len(rms))*0.007897022822395957)
plt.title("MAG_ISO",fontsize=13)
plt.xlabel("RMS",fontsize=12 )
plt.ylabel("% of total number of sources",fontsize=12)
# plt.xlim(0,)
plt.show()
# plt.hist?

# %%
len(np.where(rms>0.1)[0])/float(len(rms))
# Out:
# 0.17562978757008607

# %% [markdown]
# ### MAG_ISO_CORR_ERROR

# %%
input = np.loadtxt("input_mag")
output = np.loadtxt("output_mag")
pltx.fit_and_plot(input[::,2],output[::,2],xlabel="Input Magnitude",ylabel="Output Magnitude",title="500 RC3 Random Test",marker='.')
# Out:
# [ 0.67929799 -0.00173397]
#
# 0.6793 x - 0.001734
# poly1d([ 0.67929799, -0.00173397])

# %%
print mean(input[::,2])
print mean(output[::,2])
# Out:
# 0.088262380301
# 0.0582224842681
