# %%
cd ../pipeline_final/
# Out:
# /Users/dorislee/Desktop/GSoC2014/workarea-rc3-project/pipeline_final

# %%
from dssServer import *
dss = DSSServer()
dss.query("locstr=m101&survey=dss&mode=prog") #Make sure to specify mode=prog so that output is XML (easier to parse) not HTML
# cat result.txt
# Out:
# WARNING: AstropyDeprecationWarning: ConfigurationItem has been deprecated in astropy 0.4. Use ConfigItem objects as members of ConfigNamespace subclasses instead.  See ConfigNamespace for an example. [astropy.config.configuration]
# WARNING:astropy:AstropyDeprecationWarning: ConfigurationItem has been deprecated in astropy 0.4. Use ConfigItem objects as members of ConfigNamespace subclasses instead.  See ConfigNamespace for an example.

# %%
dss.getData('b',0.03258,-0.04058,0.05)

# %%
cat result.txt
# Out:
# <?xml version="1.0"?>
# <finderchart status="ok">
#   <input>
#     <locstr>
#       0.03258 -0.04058
#     </locstr>
#     <surveys>
#      DSS
#     </surveys>
#     <subsetsize>
#       3.0 arcmin
#     </subsetsize>
#     <orientation>
#       left
#     </orientation>
#     <reproject>
#       false
#     </reproject>
#     <grid>
#       false
#     </grid>
#     <marker>
#       false
#     </marker>
#     <shrunkgrid>
#       false
#     </shrunkgrid>
#     <shrunkmarker>
#       false
#     </shrunkmarker>
#   </input>
#   <result>
#     <datatag>
#   ADS/IRSA.FindeChart#2014/0722/235231_2417
#     </datatag>
#     <equCoord>
#       0h 0m7.82s - 0d 2m26.09s eq J2000
#     </equCoord>
#     <galCoord>
#      96.36487 -60.23874 eq J2000
#     </galCoord>
#     <eclCoord>
#      0.01375 -0.05019 ec J2000
#     </eclCoord>
#     <totalimages>
#       5
#     </totalimages>
#     <htmlfile>
#       http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/result_prt.html
#     </htmlfile>
#
#       <surveyname>
#         DSS
#       </surveyname>
#       <band>
#         dss1b
#       </band>
#       <obsdate>
#         1951-08-10
#       </obsdate>
#       <fitsurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss1_blue_sub.fits
#       </fitsurl>
#       <jpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss1_blue_sub.jpg
#       </jpgurl>
#       <shrunkjpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss1_blue_shrink.jpg
#       </shrunkjpgurl>
#
#
#       <surveyname>
#         DSS
#       </surveyname>
#       <band>
#         dss1r
#       </band>
#       <obsdate>
#         1951-08-10
#       </obsdate>
#       <fitsurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss1_red_sub.fits
#       </fitsurl>
#       <jpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss1_red_sub.jpg
#       </jpgurl>
#       <shrunkjpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss1_red_shrink.jpg
#       </shrunkjpgurl>
#
#
#       <surveyname>
#         DSS
#       </surveyname>
#       <band>
#         dss2b
#       </band>
#       <obsdate>
#         1992-11-14
#       </obsdate>
#       <fitsurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_blue_sub.fits
#       </fitsurl>
#       <jpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_blue_sub.jpg
#       </jpgurl>
#       <shrunkjpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_blue_shrink.jpg
#       </shrunkjpgurl>
#
#
#       <surveyname>
#         DSS
#       </surveyname>
#       <band>
#         dss2r
#       </band>
#       <obsdate>
#         1991-10-13
#       </obsdate>
#       <fitsurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_red_sub.fits
#       </fitsurl>
#       <jpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_red_sub.jpg
#       </jpgurl>
#       <shrunkjpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_red_shrink.jpg
#       </shrunkjpgurl>
#
#
#       <surveyname>
#         DSS
#       </surveyname>
#       <band>
#         dss2ir
#       </band>
#       <obsdate>
#         1993-10-09
#       </obsdate>
#       <fitsurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_ir_sub.fits
#       </fitsurl>
#       <jpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_ir_sub.jpg
#       </jpgurl>
#       <shrunkjpgurl>
#         http://irsa.ipac.caltech.edu/workspace/TMP_yyWMsO_2417/FinderChart/0.03258_-0.04058.v0001/poss2ukstu_ir_shrink.jpg
#       </shrunkjpgurl>
#
#   </result>
# </finderchart>
